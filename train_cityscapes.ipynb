# %%
import sys
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/DAAI')
sys.path.append('/content/drive/MyDrive/DAAI')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %%
import torch
from torch.utils.data import DataLoader
import logging
import argparse
import torch.cuda.amp as amp
import numpy as np
from tqdm import tqdm
from tensorboardX import SummaryWriter
from utils import poly_lr_scheduler
from utils import reverse_one_hot, compute_global_accuracy, fast_hist, per_class_iu
from model.model_stages import BiSeNet
from cityscapes import CityScapes
from train_cityscapes import main

# %%
if __name__ == "__main__":
    main()
# Out:
# train:1572
# val:500
# use pretrain model ./pretrain/STDCNet813M_73.91.tar
# epoch 0, lr 0.001000: 100%|██████████| 1572/1572 [24:07<00:00,  1.09it/s, loss=1.793498]
# loss for train : 2.467792
# epoch 1, lr 0.000982: 100%|██████████| 1572/1572 [03:56<00:00,  6.64it/s, loss=1.783969]
# loss for train : 1.954591
# epoch 2, lr 0.000964: 100%|██████████| 1572/1572 [03:53<00:00,  6.73it/s, loss=1.607738]
# loss for train : 1.852491
# start val!
# precision per pixel for test: 0.704
# mIoU for validation: 0.249
# mIoU per class: [0.88502706 0.40070103 0.66751892 0.02697896 0.10415486 0.12640097
#  0.00223863 0.18635173 0.76064893 0.27769745 0.73204274 0.09157209
#  0.00150221 0.45484462 0.         0.         0.         0.
#  0.00876432]
# epoch 3, lr 0.000946: 100%|██████████| 1572/1572 [03:55<00:00,  6.68it/s, loss=1.495770]
# loss for train : 1.729043
# epoch 4, lr 0.000928: 100%|██████████| 1572/1572 [03:54<00:00,  6.70it/s, loss=1.540881]
# loss for train : 1.562065
# start val!
# precision per pixel for test: 0.741
# mIoU for validation: 0.302
# mIoU per class: [0.90856729 0.45112048 0.75050434 0.05705892 0.11610669 0.15323106
#  0.07199766 0.24162245 0.8042095  0.32191143 0.74115406 0.32512796
#  0.00511395 0.59861747 0.         0.         0.         0.
#  0.18747123]
# epoch 5, lr 0.000910: 100%|██████████| 1572/1572 [03:57<00:00,  6.62it/s, loss=1.289412]
# loss for train : 1.518221
# epoch 6, lr 0.000891: 100%|██████████| 1572/1572 [03:56<00:00,  6.65it/s, loss=1.217087]
# loss for train : 1.349298
# start val!
# precision per pixel for test: 0.759
# mIoU for validation: 0.334
# mIoU per class: [9.30229798e-01 5.61707603e-01 7.62680175e-01 1.18008404e-01
#  1.44986078e-01 1.37694456e-01 7.12119473e-02 2.57574493e-01
#  8.31433658e-01 3.92594701e-01 7.87516863e-01 3.34126488e-01
#  1.25632986e-02 7.16652468e-01 0.00000000e+00 3.11917259e-04
#  5.61770401e-05 4.93759429e-05 2.90217546e-01]
# epoch 7, lr 0.000873: 100%|██████████| 1572/1572 [03:55<00:00,  6.68it/s, loss=1.172545]
# loss for train : 1.187909
# epoch 8, lr 0.000855: 100%|██████████| 1572/1572 [03:56<00:00,  6.64it/s, loss=1.315515]
# loss for train : 1.159765
# start val!
# precision per pixel for test: 0.753
# mIoU for validation: 0.327
# mIoU per class: [9.26115417e-01 5.45531477e-01 7.53686696e-01 1.10991216e-01
#  1.66909228e-01 1.50387355e-01 1.07786154e-01 1.88323010e-01
#  8.00390192e-01 3.77361849e-01 8.15897256e-01 3.63157000e-01
#  2.16042353e-02 6.85346268e-01 0.00000000e+00 1.23643608e-02
#  4.82863742e-04 0.00000000e+00 1.80705528e-01]
# epoch 9, lr 0.000836: 100%|██████████| 1572/1572 [03:56<00:00,  6.65it/s, loss=1.077302]
# loss for train : 1.239848
# epoch 10, lr 0.000818: 100%|██████████| 1572/1572 [03:55<00:00,  6.67it/s, loss=1.113967]
# loss for train : 1.060753
# start val!
# precision per pixel for test: 0.742
# mIoU for validation: 0.326
# mIoU per class: [9.10911715e-01 5.60613091e-01 7.27693983e-01 1.24322012e-01
#  1.24791696e-01 1.50203734e-01 5.96840220e-02 1.89734951e-01
#  8.07983856e-01 3.67554603e-01 8.16637881e-01 3.53314602e-01
#  2.19768698e-03 6.65202687e-01 6.50301234e-04 3.84473702e-02
#  2.29379368e-06 9.75599062e-04 2.89674067e-01]
# epoch 11, lr 0.000800: 100%|██████████| 1572/1572 [03:56<00:00,  6.65it/s, loss=1.042633]
# loss for train : 1.074047
# epoch 12, lr 0.000781: 100%|██████████| 1572/1572 [03:57<00:00,  6.61it/s, loss=0.877447]
# loss for train : 0.959769
# start val!
# precision per pixel for test: 0.774
# mIoU for validation: 0.397
# mIoU per class: [0.93278376 0.6044087  0.80547926 0.20793545 0.21286225 0.17747576
#  0.16329528 0.31560489 0.84601314 0.46180769 0.86567574 0.45261286
#  0.04957102 0.78186747 0.01976951 0.11039469 0.0556637  0.02724239
#  0.4497713 ]
# epoch 13, lr 0.000763: 100%|██████████| 1572/1572 [03:57<00:00,  6.61it/s, loss=0.831739]
# loss for train : 0.879848
# epoch 14, lr 0.000744: 100%|██████████| 1572/1572 [03:57<00:00,  6.63it/s, loss=0.796998]
# loss for train : 0.866432
# start val!
# precision per pixel for test: 0.781
# mIoU for validation: 0.421
# mIoU per class: [0.94917227 0.64955867 0.81330322 0.22587668 0.24106693 0.20606808
#  0.20022937 0.37138392 0.85206473 0.47839933 0.84466205 0.48962369
#  0.08352781 0.78428072 0.05357637 0.24420687 0.05908995 0.02496935
#  0.43066052]
# epoch 15, lr 0.000725: 100%|██████████| 1572/1572 [04:00<00:00,  6.53it/s, loss=0.800915]
# loss for train : 0.847784
# epoch 16, lr 0.000707: 100%|██████████| 1572/1572 [04:04<00:00,  6.42it/s, loss=0.769187]
# loss for train : 0.755990
# start val!
# precision per pixel for test: 0.786
# mIoU for validation: 0.439
# mIoU per class: [0.95393771 0.6819326  0.81756891 0.23457179 0.24455709 0.22961305
#  0.21032963 0.40019972 0.85593623 0.48375626 0.87368946 0.49385783
#  0.07000181 0.81264402 0.10541052 0.23162349 0.10192788 0.03979264
#  0.49870433]
# epoch 17, lr 0.000688: 100%|██████████| 1572/1572 [04:01<00:00,  6.51it/s, loss=0.801304]
# loss for train : 0.754052
# epoch 18, lr 0.000669: 100%|██████████| 1572/1572 [03:54<00:00,  6.70it/s, loss=0.745929]
# loss for train : 0.702099
# start val!
# precision per pixel for test: 0.780
# mIoU for validation: 0.444
# mIoU per class: [0.95679932 0.68922192 0.79101492 0.20012409 0.18496969 0.24754164
#  0.22449633 0.41627608 0.85287543 0.46692549 0.88568409 0.52832816
#  0.10135408 0.80577185 0.13999039 0.23604027 0.16088203 0.0575856
#  0.49480704]
# epoch 19, lr 0.000650: 100%|██████████| 1572/1572 [03:55<00:00,  6.69it/s, loss=0.696574]
# loss for train : 0.641829
# epoch 20, lr 0.000631: 100%|██████████| 1572/1572 [03:57<00:00,  6.63it/s, loss=0.639061]
# loss for train : 0.625158
# start val!
# precision per pixel for test: 0.785
# mIoU for validation: 0.448
# mIoU per class: [0.95082827 0.66018599 0.81717878 0.23039938 0.24725978 0.23838449
#  0.26603569 0.42765962 0.8559636  0.48029551 0.88401963 0.51168695
#  0.08469249 0.80546851 0.14406631 0.25816823 0.12415124 0.03752289
#  0.48725018]
# epoch 21, lr 0.000612: 100%|██████████| 1572/1572 [03:58<00:00,  6.58it/s, loss=0.547254]
# loss for train : 0.610653
# epoch 22, lr 0.000593: 100%|██████████| 1572/1572 [03:56<00:00,  6.63it/s, loss=0.593381]
# loss for train : 0.555992
# start val!
# precision per pixel for test: 0.781
# mIoU for validation: 0.446
# mIoU per class: [0.94606108 0.65330466 0.80930455 0.23036686 0.24326188 0.25100647
#  0.21399346 0.44225208 0.84987348 0.45225642 0.87793093 0.50391981
#  0.12209632 0.80526583 0.18247256 0.20249846 0.14398987 0.06983458
#  0.47244376]
# epoch 23, lr 0.000574: 100%|██████████| 1572/1572 [03:55<00:00,  6.66it/s, loss=0.514076]
# loss for train : 0.537232
# epoch 24, lr 0.000555: 100%|██████████| 1572/1572 [03:55<00:00,  6.67it/s, loss=0.497065]
# loss for train : 0.501957
# start val!
# precision per pixel for test: 0.796
# mIoU for validation: 0.486
# mIoU per class: [0.96111827 0.71391552 0.84352428 0.26847329 0.31402488 0.28751714
#  0.29742841 0.47874363 0.86092459 0.47659062 0.88197589 0.55847579
#  0.19107483 0.84102541 0.2626525  0.28767789 0.07145678 0.07715848
#  0.55462452]
# epoch 25, lr 0.000536: 100%|██████████| 1572/1572 [04:01<00:00,  6.52it/s, loss=0.448429]
# loss for train : 0.475933
# epoch 26, lr 0.000517: 100%|██████████| 1572/1572 [04:01<00:00,  6.51it/s, loss=0.431239]
# loss for train : 0.453328
# start val!
# precision per pixel for test: 0.798
# mIoU for validation: 0.498
# mIoU per class: [0.95963992 0.71282322 0.84480507 0.30245409 0.28788394 0.29695561
#  0.31365008 0.47620771 0.86686339 0.49493221 0.89561303 0.57456036
#  0.2320814  0.84416296 0.20725858 0.35036927 0.15683792 0.09033548
#  0.56310001]
# epoch 27, lr 0.000497: 100%|██████████| 1572/1572 [04:02<00:00,  6.49it/s, loss=0.440151]
# loss for train : 0.433566
# epoch 28, lr 0.000478: 100%|██████████| 1572/1572 [03:58<00:00,  6.58it/s, loss=0.393358]
# loss for train : 0.422230
# start val!
# precision per pixel for test: 0.799
# mIoU for validation: 0.500
# mIoU per class: [0.95932952 0.71296601 0.84843802 0.27862892 0.34066455 0.27865403
#  0.34149726 0.48658843 0.86997857 0.50279979 0.88794947 0.56491449
#  0.25291415 0.8423801  0.29504909 0.33477694 0.08376351 0.10132921
#  0.51517248]
# epoch 29, lr 0.000458: 100%|██████████| 1572/1572 [04:02<00:00,  6.48it/s, loss=0.388763]
# loss for train : 0.406042
# epoch 30, lr 0.000438: 100%|██████████| 1572/1572 [04:01<00:00,  6.50it/s, loss=0.366525]
# loss for train : 0.391228
# start val!
# precision per pixel for test: 0.798
# mIoU for validation: 0.499
# mIoU per class: [0.95945311 0.70890354 0.84803638 0.2567207  0.30681658 0.30587633
#  0.35855958 0.49192137 0.86883356 0.49678286 0.88058423 0.57687017
#  0.25148337 0.83064995 0.22429165 0.35799606 0.10674927 0.10295106
#  0.54921066]
# epoch 31, lr 0.000419: 100%|██████████| 1572/1572 [04:01<00:00,  6.51it/s, loss=0.375463]
# loss for train : 0.375695
# epoch 32, lr 0.000399: 100%|██████████| 1572/1572 [03:59<00:00,  6.57it/s, loss=0.337439]
# loss for train : 0.356470
# start val!
# precision per pixel for test: 0.800
# mIoU for validation: 0.507
# mIoU per class: [0.95979826 0.71410138 0.84927171 0.28502692 0.29804326 0.30181356
#  0.35592229 0.49188625 0.86886029 0.51071093 0.89484918 0.57885317
#  0.26742085 0.84369024 0.26434403 0.32048087 0.12939591 0.14768555
#  0.55221114]
# epoch 33, lr 0.000379: 100%|██████████| 1572/1572 [04:01<00:00,  6.52it/s, loss=0.338893]
# loss for train : 0.342315
# epoch 34, lr 0.000359: 100%|██████████| 1572/1572 [03:57<00:00,  6.62it/s, loss=0.310698]
# loss for train : 0.332993
# start val!
# precision per pixel for test: 0.799
# mIoU for validation: 0.500
# mIoU per class: [0.96139897 0.7193911  0.84537254 0.24376096 0.29625582 0.30717188
#  0.3485542  0.48025727 0.86802824 0.4952063  0.89333281 0.58477393
#  0.26048987 0.83875746 0.25684987 0.34321568 0.09177951 0.12288755
#  0.54236298]
# epoch 35, lr 0.000338: 100%|██████████| 1572/1572 [03:58<00:00,  6.59it/s, loss=0.300472]
# loss for train : 0.323959
# epoch 36, lr 0.000318: 100%|██████████| 1572/1572 [03:58<00:00,  6.58it/s, loss=0.290353]
# loss for train : 0.312112
# start val!
# precision per pixel for test: 0.799
# mIoU for validation: 0.498
# mIoU per class: [0.96051059 0.71609616 0.84755473 0.24759863 0.28550522 0.32301052
#  0.3509887  0.4656658  0.86579769 0.50150071 0.89301989 0.57067313
#  0.243266   0.84842167 0.25905822 0.30957691 0.1230311  0.10956211
#  0.53730178]
# epoch 37, lr 0.000297: 100%|██████████| 1572/1572 [03:57<00:00,  6.61it/s, loss=0.279353]
# loss for train : 0.302765
# epoch 38, lr 0.000277: 100%|██████████| 1572/1572 [03:56<00:00,  6.65it/s, loss=0.274573]
# loss for train : 0.295907
# start val!
# precision per pixel for test: 0.800
# mIoU for validation: 0.500
# mIoU per class: [0.96015875 0.71182739 0.8472149  0.24622292 0.28987645 0.31939664
#  0.33951112 0.46036293 0.86914795 0.51403567 0.89652203 0.5834614
#  0.25313475 0.85448214 0.28346732 0.29807606 0.09747528 0.11749876
#  0.55860415]
# epoch 39, lr 0.000256: 100%|██████████| 1572/1572 [03:58<00:00,  6.59it/s, loss=0.267184]
# loss for train : 0.287350
# epoch 40, lr 0.000235: 100%|██████████| 1572/1572 [03:58<00:00,  6.58it/s, loss=0.262133]
# loss for train : 0.277723
# start val!
# precision per pixel for test: 0.797
# mIoU for validation: 0.489
# mIoU per class: [0.95978547 0.71088273 0.84111875 0.24773257 0.28888558 0.31102962
#  0.32270775 0.42548158 0.86593509 0.49652846 0.89713249 0.56813637
#  0.21584267 0.84285372 0.22168903 0.30917783 0.10717682 0.10024852
#  0.55872103]
# epoch 41, lr 0.000214: 100%|██████████| 1572/1572 [04:00<00:00,  6.55it/s, loss=0.256661]
# loss for train : 0.270967
# epoch 42, lr 0.000192: 100%|██████████| 1572/1572 [03:59<00:00,  6.55it/s, loss=0.254558]
# loss for train : 0.264506
# start val!
# precision per pixel for test: 0.799
# mIoU for validation: 0.497
# mIoU per class: [0.95988059 0.71017714 0.84700741 0.25063486 0.28035552 0.32938788
#  0.33757347 0.48019501 0.86771597 0.49488    0.89745975 0.5827509
#  0.23350956 0.84627308 0.21873535 0.33730372 0.0721757  0.11685197
#  0.57189412]
# epoch 43, lr 0.000170: 100%|██████████| 1572/1572 [04:04<00:00,  6.42it/s, loss=0.250209]
# loss for train : 0.259805
# epoch 44, lr 0.000148: 100%|██████████| 1572/1572 [04:02<00:00,  6.48it/s, loss=0.243245]
# loss for train : 0.254150
# start val!
