# %%
import sys
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/DAAI')
sys.path.append('/content/drive/MyDrive/DAAI')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %%
from model.model_stages import BiSeNet
from gta5 import Gta5
from cityscapes import CityScapes
import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
import logging
import argparse
import numpy as np
from tensorboardX import SummaryWriter
import torch.cuda.amp as amp
from utils import poly_lr_scheduler
from utils import reverse_one_hot, compute_global_accuracy, fast_hist, per_class_iu
from tqdm import tqdm
import os
from train_gta5_orig_aug_fda import main

# %%
if __name__ == "__main__":
    seldata = 'train_fda' # For original data: 'train'; For fda data: 'train_fda'
    setaug = 0 # For data augment:set True; Otherwise: set Fasle
    main(seldata,setaug)
# Out:
# train_fda:1750
# val_fda:750
# use pretrain model ./pretrain/STDCNet813M_73.91.tar
# epoch 33, lr 0.000379: 100%|██████████| 1750/1750 [08:11<00:00,  3.56it/s, loss=0.561228]
# loss for train : 0.463436
# epoch 34, lr 0.000359: 100%|██████████| 1750/1750 [02:35<00:00, 11.29it/s, loss=0.428940]
# loss for train : 0.455840
# start val!
# precision per pixel for test: 0.776
# mIoU for validation: 0.446
# mIoU per class: [0.95889744 0.65447807 0.77259383 0.48388649 0.16859877 0.33413413
#  0.31695972 0.28670942 0.73829807 0.5219649  0.93511125 0.23287057
#  0.12383519 0.70899236 0.44707882 0.33264089 0.15918492 0.29086797
#  0.00768386]
# epoch 35, lr 0.000338: 100%|██████████| 1750/1750 [02:35<00:00, 11.26it/s, loss=0.400500]
# loss for train : 0.426095
# epoch 36, lr 0.000318: 100%|██████████| 1750/1750 [02:35<00:00, 11.24it/s, loss=0.376543]
# loss for train : 0.410536
# start val!
# precision per pixel for test: 0.781
# mIoU for validation: 0.460
# mIoU per class: [0.96334221 0.68037701 0.77820187 0.47261378 0.17124056 0.34064649
#  0.31593117 0.23748167 0.73693324 0.57536749 0.93654995 0.25179983
#  0.10787039 0.72969298 0.45836612 0.40596493 0.33246178 0.24217187
#  0.00374981]
# epoch 37, lr 0.000297: 100%|██████████| 1750/1750 [02:41<00:00, 10.84it/s, loss=0.372605]
# loss for train : 0.401036
# epoch 38, lr 0.000277: 100%|██████████| 1750/1750 [02:38<00:00, 11.01it/s, loss=0.382586]
# loss for train : 0.395757
# start val!
# precision per pixel for test: 0.781
# mIoU for validation: 0.466
# mIoU per class: [0.96425138 0.69419363 0.78422561 0.4661137  0.19222997 0.3431471
#  0.31689671 0.25570274 0.73792751 0.55929613 0.93798086 0.26531177
#  0.14271824 0.72084904 0.46767379 0.36705908 0.30030269 0.32403108
#  0.00936524]
# epoch 39, lr 0.000256: 100%|██████████| 1750/1750 [02:37<00:00, 11.14it/s, loss=0.356027]
# loss for train : 0.386656
# epoch 40, lr 0.000235: 100%|██████████| 1750/1750 [02:35<00:00, 11.24it/s, loss=0.343655]
# loss for train : 0.383347
# start val!
# precision per pixel for test: 0.783
# mIoU for validation: 0.470
# mIoU per class: [0.96491177 0.69562467 0.78600428 0.48057616 0.18882802 0.34351177
#  0.31361645 0.26624217 0.74144318 0.58780527 0.93745191 0.25435743
#  0.11735043 0.72958226 0.47470695 0.39381966 0.32415902 0.30696905
#  0.0146826 ]
# epoch 41, lr 0.000214: 100%|██████████| 1750/1750 [02:36<00:00, 11.17it/s, loss=0.330459]
# loss for train : 0.373029
# epoch 42, lr 0.000192: 100%|██████████| 1750/1750 [02:36<00:00, 11.20it/s, loss=0.323762]
# loss for train : 0.363815
# start val!
# precision per pixel for test: 0.783
# mIoU for validation: 0.463
# mIoU per class: [0.96428677 0.70498725 0.79113912 0.47634823 0.18937316 0.34693667
#  0.33003525 0.26433407 0.73841463 0.58373306 0.93837499 0.26030703
#  0.11873097 0.72832017 0.47054787 0.37179597 0.25600882 0.25439216
#  0.        ]
# epoch 43, lr 0.000170: 100%|██████████| 1750/1750 [02:35<00:00, 11.22it/s, loss=0.318422]
# loss for train : 0.356997
# epoch 44, lr 0.000148: 100%|██████████| 1750/1750 [02:35<00:00, 11.22it/s, loss=0.317732]
# loss for train : 0.352140
# start val!
# precision per pixel for test: 0.783
# mIoU for validation: 0.464
# mIoU per class: [0.9647142  0.70671628 0.79675263 0.47871567 0.18633621 0.35929972
#  0.34254202 0.27114392 0.73212927 0.58966932 0.93843511 0.2547197
#  0.13037801 0.7318173  0.47365815 0.3744043  0.21527792 0.26018594
#  0.01524468]
# epoch 45, lr 0.000126: 100%|██████████| 1750/1750 [02:36<00:00, 11.21it/s, loss=0.314892]
# loss for train : 0.347957
# epoch 46, lr 0.000103: 100%|██████████| 1750/1750 [02:36<00:00, 11.20it/s, loss=0.309958]
# loss for train : 0.343061
# start val!
# precision per pixel for test: 0.783
# mIoU for validation: 0.464
# mIoU per class: [9.65141159e-01 7.03600950e-01 7.96044647e-01 4.76972141e-01
#  1.68046058e-01 3.67765009e-01 3.49398895e-01 2.76977169e-01
#  7.23462280e-01 5.98588881e-01 9.38702236e-01 2.62729993e-01
#  1.29960593e-01 7.29510850e-01 4.64917418e-01 3.67221580e-01
#  2.34549735e-01 2.66848846e-01 7.06913614e-04]
# epoch 47, lr 0.000079: 100%|██████████| 1750/1750 [02:38<00:00, 11.05it/s, loss=0.306900]
# loss for train : 0.338596
# epoch 48, lr 0.000055: 100%|██████████| 1750/1750 [02:35<00:00, 11.28it/s, loss=0.303055]
# loss for train : 0.334635
# start val!
# precision per pixel for test: 0.783
# mIoU for validation: 0.468
# mIoU per class: [9.64738889e-01 6.99419848e-01 7.94574576e-01 4.77688364e-01
#  1.68335447e-01 3.77743553e-01 3.53683628e-01 2.81958997e-01
#  7.26034466e-01 6.00923121e-01 9.38423502e-01 2.70261257e-01
#  1.36141098e-01 7.29024763e-01 4.63101799e-01 3.64415946e-01
#  2.44583246e-01 2.92018157e-01 4.34404865e-04]
# epoch 49, lr 0.000030: 100%|██████████| 1750/1750 [02:38<00:00, 11.08it/s, loss=0.304070]
# loss for train : 0.332701
# start val!
# precision per pixel for test: 0.784
# mIoU for validation: 0.469
# mIoU per class: [9.64741112e-01 7.00132986e-01 7.94577134e-01 4.72768155e-01
#  1.69955250e-01 3.78163900e-01 3.50743115e-01 2.82293640e-01
#  7.38406204e-01 5.99934233e-01 9.38363313e-01 2.70702502e-01
#  1.50122176e-01 7.30714707e-01 4.64708920e-01 3.64391278e-01
#  2.57424184e-01 2.81794999e-01 2.86944045e-04]
